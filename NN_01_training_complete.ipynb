# %%
#0 OR 1 NUERAL NETWORK DETECTOR ~95% accuracy, although may vary from low to high 90's for accuracy

#BY: Rahul.Gudise
# https://github.com/Chipsandnonos

#Trained using the MNIST database, acessed here http://yann.lecun.com/exdb/mnist/
#Developed using NUMPY

#Feel free to fork, and send in suggestions for improvements

import numpy
from mnist import MNIST

# %%
ndata = MNIST('samples')
images_train, labels_train = ndata.load_training()
images_test, labels_test = ndata.load_testing()

# %%
#The "squish" function choosen for this particular Nueral Network is the sigmoid (logistic) curve
def sigmoid(x): 
    return 1/(1+numpy.exp(-x))

#This is the derivative of the sigmoid curve
def sigmoid_p(x):
    return sigmoid(x) * (1-sigmoid(x))

# %%
#NETWORK STRUCTURE
# The goal of this Nueral Network is to detect whether a 28x28 grayscale imageis that of a 1 or 0

#Due to there only being 2 answers, a compact Neural Network structure was picked
#Layer 1 consists of 784 nuerons, each corresponding to a pixel within the original 28x28 image
#Layer 2 consists of 5 nuerons
#Layer 3 consists of 1 nueron, which when it has an activation of 1, signifies the input was a 1, and when 0, means the input was 0


#ALL GLOBAL VARIABLES
pic_size = 28              #The size of the original grayscale picture                
lay1_size = pic_size**2    #Size of the first layer (28x28)
lay2_size = 5           #Size of the second layer (5)
lay3_size = 1              #Size of the third layer (1))

#HYPERPARAMTER 
learn_rate = .01   #The learning rate of the nueral network, a small value was chosen so that the change vector would not
                     #overshoot when adjusting the weights and biases for the cost function

# %%
#Will Pick out only 1's and 0's in MNIST TRAINING DATASET
num_shift = 0
for i in range(len(labels_train)):
    
    if not (labels_train[i-num_shift] == 0 or labels_train[i-num_shift] == 1) :
        images_train.pop(i-num_shift)
        labels_train.pop(i-num_shift)
        num_shift = num_shift +1
   
        

#Will Pick out only 1's and 0's in MNIST TESTING DATASET
num_shift = 0

for i in range(len(labels_test)):
    
    if not (labels_test[i-num_shift] == 0 or labels_test[i-num_shift] == 1) :
        labels_test.pop(i-num_shift)
        images_test.pop(i-num_shift)
        num_shift = num_shift +1

# %%
#A function which will take all grayscale pixel values in an original MNIST data piece and transfer into the activations
#of the first layer nuerons
#The value "scale", is there simply to convert the grayscale value (0-255), into a number which can be inputted into the nueron
#Nueron domain is 0-1

def img_to_activation(layer1A, image):
    scale = 1/255
    
    for i in range(lay1_size):
        layer1A[i] = image[i]*scale
    
    return layer1A

# %%
#A function which will take in the activations of 1st layer nuerons, and with the weights and biases of all layers, to 
#computer the appropriate activations of 2nd and 3rd layer nuerons 
def find_activation(layer1A, layer2A, layer3A, weight21, weight32, bias21, bias32): #need to use the biases too
    
    
    layer2A = numpy.matmul(weight21, layer1A)
    
    for i in range(lay2_size):
        layer2A[i] = layer2A[i] + bias21[i]
    
    for i in range(lay2_size):
        layer2A[i] = sigmoid(layer2A[i])
    
    layer3A = numpy.matmul(weight32, layer2A)
    layer3A = layer3A + bias32
    layer3A = sigmoid(layer3A)
   
    return layer2A, layer3A

# %%
#A function which will calculate the change vector which points in the direction of greatest ascent of the cost function
#When given the all activations of all nuerons on all layers, and all weights and biases 
def deriv_fill(layer1A, layer2A, layer3A, weight21, weight32, bias21, bias32, actual):
    
    #Change Matrices
    
    cweightL1 = numpy.zeros((lay2_size,lay1_size), dtype = float)
    cweightL2 = numpy.zeros((lay2_size),dtype = float )
    
    cbiasL1 = numpy.zeros((lay2_size),dtype = float )
    cbiasL2 = numpy.zeros((lay3_size),dtype = float )
   
    #Constants needed to compute derivatives 
    pred = layer3A
    z = 0
    for i in range(lay2_size):
        z = layer2A[i] * weight32[i]
    z = z + bias32
    
    num_w_2 = lay2_size 
    num_w_1 = lay1_size*lay2_size 
    #--------------------------------------- Derivatives
          
    dc_dsig = 2*(pred-actual)
    dsig_dz = sigmoid_p(z)
    
    #dz_d(any layer 2 weight) = activation, bias = 1
    
    for i in range(lay2_size):
        dz_dw0i = layer2A[i]
        cweightL2[i] = dc_dsig*dsig_dz*dz_dw0i
    cbiasL2[0] = dc_dsig*dsig_dz
    
    for i in range(lay2_size):
        cbiasL1[i] = 1
        dz_da2i = weight32[i]
        for y in range (lay1_size):
            da2i_dwiy = layer1A[y]
            cweightL1[i][y] =  dc_dsig*dsig_dz*dz_da2i*da2i_dwiy

    
  
    return cweightL1,cweightL2,cbiasL1,cbiasL2

# %%
#A function which will update all parameters (weights and biases), based on previously calculated direction vector
def update_val(layer1A, layer2A, layer3A, weight21, weight32, bias21, bias32, cweightL1,cweightL2,cbiasL1,cbiasL2 ):
     #updates weights connecting layers 1-2    
    for i in range (lay2_size):
        for y in range (lay1_size):
            weight21[i][y] = weight21[i][y] - (learn_rate*cweightL1[i][y])
    
        #updates weights connected layers 2-3
    for i in range (lay2_size):
        weight32[i] = weight32[i] - (learn_rate*cweightL2[i])
    
        #updates biases in layer 2 nuerons
    for i in range (lay2_size):
        bias21[i] = bias21[i] - (learn_rate*bias21[i])
    
        #updates biases in layer 3 nuerons
    bias32[0] = bias32[0] - (learn_rate*cbiasL2[0])
    
    return weight21, weight32, bias21, bias32

# %%
#A function which will input a TEST data piece and see the nueral network's output
def ask(image, weight21, weight32, bias21, bias32,layer1A,layer2A,layer3A):
    layer1A = img_to_activation(layer1A, image)
    layer2A, layer3A = find_activation(layer1A, layer2A, layer3A, weight21, weight32, bias21, bias32)
    
    return layer3A

# %%
#A function which handles the output of the network after being asked to identify a data piece 
def test(index, weight21,weight32,bias21,bias32,layer1A,layer2A,layer3A):
    pred = ask(images_test[index], weight21, weight32, bias21, bias32,layer1A,layer2A,layer3A)
    actual = labels_test[index]
    num = 0
    succeed = 0.0
    adj = 0
    cost = (pred - actual)**2
    if (pred>.5):
        num = 1
        adj = 0
    else:
        num = 0
        adj = 1
    
    if (num == actual):
        succeed = 1.0
    else:
        succeed = 0.0
    
    print(f"Computer: {num}, with a {adj - pred}%")
    print(f"Actually: {actual}, with a cost of {cost}")
    return succeed

# %%
#The function which ties together all of the above training functions, and trains the nueral network
def train():
       
    #To avoid refering to global variables as much, all matrices and vectors were defined here, and transfered between functions as needed
    
    #Activations -- All Activations of nuerons are held here
    layer1A = numpy.zeros((lay1_size),dtype = float )
    layer2A = numpy.zeros((lay2_size),dtype = float )
    layer3A = numpy.zeros((lay3_size),dtype = float )

    #Weights -- All weights are stored here
    weight21 = numpy.zeros((lay2_size,lay1_size), dtype = float)
    weight32 = numpy.zeros((lay2_size),dtype = float )

    #Biases -- All biases are stored here
    bias21 = numpy.zeros((lay2_size),dtype = float )
    bias32 = numpy.zeros((lay3_size),dtype = float )
    
    #Weights and biases start of random, as such this will randomize all enteries in the weight and bias matrices 
    
    #Randomizes all biases and weights in layers 1-2
    for i in range(lay2_size):
        bias21[i] = numpy.random.randn()
        for y in range(lay1_size):
            weight21[i][y] = numpy.random.randn()

    #Randomizes all biases and weights in layers 2-3
    for i in range(5):
        weight32[i] = numpy.random.randn()

    bias32[0] = numpy.random.randn()

    #--------------- Training Process
           #1. Transfers the pixel grayscale values into Layer 1 nueron activations
           #2. Finds the activations of all the other layers
           #3. Finds the appropriate direction vector to find direction of greatest ascent in cost function
           #4. Updates all bias and weights based on the aforementioned direction vector
            
    for i in range (len(labels_train)):
        layer1A = img_to_activation(layer1A, images_train[i])
        layer2A, layer3A = find_activation(layer1A, layer2A, layer3A, weight21, weight32, bias21, bias32)
        cweightL1,cweightL2,cbiasL1,cbiasL2 = deriv_fill(layer1A, layer2A, layer3A, weight21, weight32, bias21, bias32, labels_train[i])
        weight21, weight32, bias21, bias32 = update_val(layer1A, layer2A, layer3A, weight21, weight32, bias21, bias32, cweightL1,cweightL2,cbiasL1,cbiasL2 )
        
        #A small piece of code to output every 100th cost, so that you can monitor the network's progress
        cost = (layer3A - labels_train[i])**2
        if i%100 == 0:
            print (cost)
    
    #Wipes all layer's nueron's activations
    layer1A = numpy.zeros((lay1_size),dtype = float )
    layer2A = numpy.zeros((lay2_size),dtype = float )
    layer3A = numpy.zeros((lay3_size),dtype = float )
    
    return weight21,weight32,bias21,bias32,layer1A,layer2A,layer3A

# %%
#Trains the network
weight21,weight32,bias21,bias32,layer1A,layer2A,layer3A = train()
# Out:
# [0.63159383]
# [0.0012756]
# [0.37278803]
# [0.03365413]
# [0.24271849]
# [0.20591414]
# [0.18382802]
# [0.15089502]
# [0.23597964]
# [0.11905404]
# [0.05621063]
# [0.34692585]
# [0.08340025]
# [0.00316071]
# [0.06748741]
# [0.00111331]
# [0.00175009]
# [0.00037818]
# [0.00137303]
# [0.19187719]
# [0.04207577]
# [0.03597878]
# [0.6593843]
# [0.00034191]
# [0.10838397]
# [0.02683998]
# [0.02498412]
# [0.00072166]
# [0.02435006]
# [0.00025158]
# [0.02230951]
# [0.0002864]
# [0.02154549]
# [0.00056502]
# [0.01966806]
# [0.01857581]
# [0.00129228]
# [0.01700857]
# [0.01073564]
# [0.00109116]
# [0.01462393]
# [0.01408108]
# [0.01298052]
# [0.01263293]
# [0.01187953]
# [0.01155364]
# [0.000164]
# [0.00015769]
# [0.00026483]
# [0.0098742]
# [0.4989028]
# [0.00926379]
# [0.00930733]
# [0.00902361]
# [0.00864848]
# [0.00852434]
# [0.00835899]
# [0.00799468]
# [0.00012544]
# [0.00012432]
# [0.00669511]
# [0.00652749]
# [0.00012325]
# [0.00641157]
# [0.00628175]
# [7.75093918e-05]
# [0.00608505]
# [0.00010718]
# [0.00453143]
# [9.45332044e-05]
# [0.000221]
# [9.16298684e-05]
# [0.00610294]
# [0.00598788]
# [8.70865464e-05]
# [0.00563943]
# [0.00553152]
# [8.57857367e-05]
# [0.00507907]
# [7.93717677e-05]
# [6.43356645e-05]
# [7.76113967e-05]
# [0.00495477]
# [0.00478105]
# [0.00491926]
# [0.00045535]
# [0.00439648]
# [0.00425049]
# [7.34196632e-05]
# [4.89701175e-05]
# [0.00414413]
# [0.00406404]
# [6.86129068e-05]
# [0.00367404]
# [0.5486427]
# [3.70503769e-05]
# [6.40770521e-05]
# [0.00369375]
# [0.00363235]
# [6.27148664e-05]
# [0.00333288]
# [0.00326414]
# [6.11624433e-05]
# [0.12176185]
# [0.00294794]
# [0.89192806]
# [0.00304558]
# [0.00298064]
# [5.33641989e-05]
# [4.45792515e-05]
# [5.29762515e-05]
# [0.00303876]
# [0.00304914]
# [5.083281e-05]
# [0.0028832]
# [5.2132906e-05]
# [0.00270707]
# [3.60939031e-05]
# [0.00249189]
# [4.9044064e-05]
# [0.00246242]
# [4.95073055e-05]
# [0.00232026]
# [4.93814214e-05]
# [4.96611249e-05]
# [4.98500006e-05]
# [4.86303337e-05]

# %%
#Small piece of code to run through the MNIST TEST DATA through the trained nueral network

accuracy = 0
for i in range(len(labels_test)):
    counter = test(i, weight21,weight32,bias21,bias32,layer1A,layer2A,layer3A)
    accuracy = accuracy + counter

p_accuracy = accuracy/len(labels_test)
print(f"Computer finished testing with a final accuracy of: {p_accuracy}")
# Out:
# Computer: 1, with a [-0.993118]%
# Actually: 1, with a cost of [4.73619028e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931249]%
# Actually: 1, with a cost of [4.72669475e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.993118]%
# Actually: 1, with a cost of [4.73619244e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99404002]%
# Actually: 1, with a cost of [3.55214084e-05]
# Computer: 1, with a [-0.99484197]%
# Actually: 1, with a cost of [2.66052463e-05]
# Computer: 1, with a [-0.99366456]%
# Actually: 1, with a cost of [4.01377418e-05]
# Computer: 1, with a [-0.99311766]%
# Actually: 1, with a cost of [4.7366592e-05]
# Computer: 1, with a [-0.99317618]%
# Actually: 1, with a cost of [4.65645308e-05]
# Computer: 1, with a [-0.92159704]%
# Actually: 1, with a cost of [0.00614702]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312675]%
# Actually: 1, with a cost of [4.72415304e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931179]%
# Actually: 1, with a cost of [4.73632502e-05]
# Computer: 1, with a [-0.99311834]%
# Actually: 1, with a cost of [4.73572655e-05]
# Computer: 1, with a [-0.99311801]%
# Actually: 1, with a cost of [4.73617885e-05]
# Computer: 1, with a [-0.99034832]%
# Actually: 1, with a cost of [9.31549971e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311782]%
# Actually: 1, with a cost of [4.73644617e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311938]%
# Actually: 1, with a cost of [4.7342917e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931186]%
# Actually: 1, with a cost of [4.73536515e-05]
# Computer: 1, with a [-0.99311801]%
# Actually: 1, with a cost of [4.7361724e-05]
# Computer: 1, with a [-0.99264176]%
# Actually: 1, with a cost of [5.41437597e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99473493]%
# Actually: 1, with a cost of [2.77209188e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99316093]%
# Actually: 1, with a cost of [4.67729079e-05]
# Computer: 1, with a [-0.99312649]%
# Actually: 1, with a cost of [4.72451534e-05]
# Computer: 1, with a [-0.99312358]%
# Actually: 1, with a cost of [4.7285121e-05]
# Computer: 1, with a [-0.99312851]%
# Actually: 1, with a cost of [4.72173095e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99481527]%
# Actually: 1, with a cost of [2.68813944e-05]
# Computer: 1, with a [-0.99311786]%
# Actually: 1, with a cost of [4.73638626e-05]
# Computer: 1, with a [-0.98968086]%
# Actually: 1, with a cost of [0.00010648]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311795]%
# Actually: 1, with a cost of [4.73625687e-05]
# Computer: 1, with a [-0.9931182]%
# Actually: 1, with a cost of [4.73591232e-05]
# Computer: 1, with a [-0.99384902]%
# Actually: 1, with a cost of [3.78345128e-05]
# Computer: 1, with a [-0.99311794]%
# Actually: 1, with a cost of [4.73627189e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931183]%
# Actually: 1, with a cost of [4.73577478e-05]
# Computer: 1, with a [-0.99311805]%
# Actually: 1, with a cost of [4.7361232e-05]
# Computer: 1, with a [-0.99439745]%
# Actually: 1, with a cost of [3.13885473e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.96378524]%
# Actually: 1, with a cost of [0.00131151]
# Computer: 1, with a [-0.99312415]%
# Actually: 1, with a cost of [4.72772605e-05]
# Computer: 1, with a [-0.9931281]%
# Actually: 1, with a cost of [4.7223049e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99371614]%
# Actually: 1, with a cost of [3.94868683e-05]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73637673e-05]
# Computer: 1, with a [-0.99366436]%
# Actually: 1, with a cost of [4.01403423e-05]
# Computer: 1, with a [-0.99311791]%
# Actually: 1, with a cost of [4.73631257e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99327087]%
# Actually: 1, with a cost of [4.52811323e-05]
# Computer: 0, with a [0.95341323]%
# Actually: 0, with a cost of [0.00217033]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99327823]%
# Actually: 1, with a cost of [4.51822226e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99313095]%
# Actually: 1, with a cost of [4.71838138e-05]
# Computer: 1, with a [-0.99313998]%
# Actually: 1, with a cost of [4.70598796e-05]
# Computer: 1, with a [-0.99313558]%
# Actually: 1, with a cost of [4.71202074e-05]
# Computer: 1, with a [-0.99312323]%
# Actually: 1, with a cost of [4.72899791e-05]
# Computer: 1, with a [-0.99316302]%
# Actually: 1, with a cost of [4.67442633e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311785]%
# Actually: 1, with a cost of [4.736404e-05]
# Computer: 1, with a [-0.99424546]%
# Actually: 1, with a cost of [3.31146806e-05]
# Computer: 1, with a [-0.99311893]%
# Actually: 1, with a cost of [4.73490864e-05]
# Computer: 1, with a [-0.99282569]%
# Actually: 1, with a cost of [5.14706945e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341327]%
# Actually: 0, with a cost of [0.00217032]
# Computer: 1, with a [-0.99312212]%
# Actually: 1, with a cost of [4.73051962e-05]
# Computer: 1, with a [-0.9931182]%
# Actually: 1, with a cost of [4.73591994e-05]
# Computer: 0, with a [0.95129827]%
# Actually: 0, with a cost of [0.00237186]
# Computer: 1, with a [-0.99311871]%
# Actually: 1, with a cost of [4.73521712e-05]
# Computer: 1, with a [-0.99311874]%
# Actually: 1, with a cost of [4.73517501e-05]
# Computer: 1, with a [-0.99311846]%
# Actually: 1, with a cost of [4.73556519e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311635]%
# Actually: 1, with a cost of [4.73846283e-05]
# Computer: 1, with a [-0.99311905]%
# Actually: 1, with a cost of [4.73474595e-05]
# Computer: 1, with a [-0.99359288]%
# Actually: 1, with a cost of [4.10511701e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99389065]%
# Actually: 1, with a cost of [3.73242157e-05]
# Computer: 1, with a [-0.993118]%
# Actually: 1, with a cost of [4.73619622e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311804]%
# Actually: 1, with a cost of [4.73614014e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99435409]%
# Actually: 1, with a cost of [3.18763017e-05]
# Computer: 1, with a [-0.99312715]%
# Actually: 1, with a cost of [4.72360162e-05]
# Computer: 1, with a [-0.99311874]%
# Actually: 1, with a cost of [4.73517627e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311846]%
# Actually: 1, with a cost of [4.73555866e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99333386]%
# Actually: 1, with a cost of [4.44373872e-05]
# Computer: 1, with a [-0.99311825]%
# Actually: 1, with a cost of [4.73584529e-05]
# Computer: 1, with a [-0.9928405]%
# Actually: 1, with a cost of [5.12583948e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312381]%
# Actually: 1, with a cost of [4.72819378e-05]
# Computer: 1, with a [-0.99311789]%
# Actually: 1, with a cost of [4.73634228e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99421265]%
# Actually: 1, with a cost of [3.3493422e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.98924808]%
# Actually: 1, with a cost of [0.0001156]
# Computer: 0, with a [0.74177145]%
# Actually: 1, with a cost of [0.55022488]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9933579]%
# Actually: 1, with a cost of [4.41175173e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99474784]%
# Actually: 1, with a cost of [2.75851619e-05]
# Computer: 1, with a [-0.99316555]%
# Actually: 1, with a cost of [4.67097506e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99317672]%
# Actually: 1, with a cost of [4.65571223e-05]
# Computer: 1, with a [-0.9931179]%
# Actually: 1, with a cost of [4.73632435e-05]
# Computer: 1, with a [-0.99312803]%
# Actually: 1, with a cost of [4.72239376e-05]
# Computer: 1, with a [-0.99339069]%
# Actually: 1, with a cost of [4.36830349e-05]
# Computer: 1, with a [-0.99312491]%
# Actually: 1, with a cost of [4.72668489e-05]
# Computer: 1, with a [-0.99417151]%
# Actually: 1, with a cost of [3.39712411e-05]
# Computer: 1, with a [-0.9933975]%
# Actually: 1, with a cost of [4.35930303e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311894]%
# Actually: 1, with a cost of [4.73490265e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341336]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311817]%
# Actually: 1, with a cost of [4.73596254e-05]
# Computer: 1, with a [-0.99341755]%
# Actually: 1, with a cost of [4.33285893e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311816]%
# Actually: 1, with a cost of [4.73597167e-05]
# Computer: 1, with a [-0.99311812]%
# Actually: 1, with a cost of [4.73602978e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311859]%
# Actually: 1, with a cost of [4.73538683e-05]
# Computer: 1, with a [-0.99453884]%
# Actually: 1, with a cost of [2.9824264e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99314435]%
# Actually: 1, with a cost of [4.699996e-05]
# Computer: 1, with a [-0.99311807]%
# Actually: 1, with a cost of [4.73609174e-05]
# Computer: 1, with a [-0.99460536]%
# Actually: 1, with a cost of [2.91021034e-05]
# Computer: 1, with a [-0.99374463]%
# Actually: 1, with a cost of [3.9129598e-05]
# Computer: 1, with a [-0.99315863]%
# Actually: 1, with a cost of [4.68043019e-05]
# Computer: 1, with a [-0.99310507]%
# Actually: 1, with a cost of [4.75401253e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99463041]%
# Actually: 1, with a cost of [2.88325235e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312096]%
# Actually: 1, with a cost of [4.73211314e-05]
# Computer: 1, with a [-0.99042656]%
# Actually: 1, with a cost of [9.16506857e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311789]%
# Actually: 1, with a cost of [4.73634723e-05]
# Computer: 1, with a [-0.99311791]%
# Actually: 1, with a cost of [4.73631326e-05]
# Computer: 1, with a [-0.99311869]%
# Actually: 1, with a cost of [4.73523827e-05]
# Computer: 1, with a [-0.99312398]%
# Actually: 1, with a cost of [4.72795826e-05]
# Computer: 1, with a [-0.99311794]%
# Actually: 1, with a cost of [4.73628016e-05]
# Computer: 1, with a [-0.99311791]%
# Actually: 1, with a cost of [4.736317e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931186]%
# Actually: 1, with a cost of [4.73536316e-05]
# Computer: 1, with a [-0.99311833]%
# Actually: 1, with a cost of [4.7357434e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99318185]%
# Actually: 1, with a cost of [4.6487221e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.91608903]%
# Actually: 1, with a cost of [0.00704105]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99316428]%
# Actually: 1, with a cost of [4.67270283e-05]
# Computer: 1, with a [-0.99415743]%
# Actually: 1, with a cost of [3.41355835e-05]
# Computer: 1, with a [-0.99314632]%
# Actually: 1, with a cost of [4.69729253e-05]
# Computer: 1, with a [-0.99312373]%
# Actually: 1, with a cost of [4.72830551e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.994148]%
# Actually: 1, with a cost of [3.42459369e-05]
# Computer: 1, with a [-0.99313879]%
# Actually: 1, with a cost of [4.70762484e-05]
# Computer: 0, with a [0.75346875]%
# Actually: 1, with a cost of [0.56771516]
# Computer: 1, with a [-0.99315085]%
# Actually: 1, with a cost of [4.69109142e-05]
# Computer: 1, with a [-0.9931198]%
# Actually: 1, with a cost of [4.73371078e-05]
# Computer: 1, with a [-0.99311812]%
# Actually: 1, with a cost of [4.73602111e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931181]%
# Actually: 1, with a cost of [4.7360522e-05]
# Computer: 1, with a [-0.99438005]%
# Actually: 1, with a cost of [3.15838603e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931742]%
# Actually: 1, with a cost of [4.65915744e-05]
# Computer: 1, with a [-0.99013483]%
# Actually: 1, with a cost of [9.73215994e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.69600716]%
# Actually: 1, with a cost of [0.48442597]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9894475]%
# Actually: 1, with a cost of [0.00011136]
# Computer: 1, with a [-0.99343922]%
# Actually: 1, with a cost of [4.30437964e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312228]%
# Actually: 1, with a cost of [4.73030585e-05]
# Computer: 1, with a [-0.9931257]%
# Actually: 1, with a cost of [4.72559622e-05]
# Computer: 1, with a [-0.993118]%
# Actually: 1, with a cost of [4.73618784e-05]
# Computer: 1, with a [-0.9931183]%
# Actually: 1, with a cost of [4.73578317e-05]
# Computer: 1, with a [-0.99311879]%
# Actually: 1, with a cost of [4.73510728e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312285]%
# Actually: 1, with a cost of [4.72951621e-05]
# Computer: 1, with a [-0.99320573]%
# Actually: 1, with a cost of [4.61620495e-05]
# Computer: 1, with a [-0.9931223]%
# Actually: 1, with a cost of [4.73027381e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312048]%
# Actually: 1, with a cost of [4.7327853e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99313133]%
# Actually: 1, with a cost of [4.71786761e-05]
# Computer: 1, with a [-0.99485499]%
# Actually: 1, with a cost of [2.64711404e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311725]%
# Actually: 1, with a cost of [4.73722965e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311783]%
# Actually: 1, with a cost of [4.7364291e-05]
# Computer: 1, with a [-0.99311802]%
# Actually: 1, with a cost of [4.73616959e-05]
# Computer: 1, with a [-0.99355703]%
# Actually: 1, with a cost of [4.15118733e-05]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73636535e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99391537]%
# Actually: 1, with a cost of [3.70226848e-05]
# Computer: 1, with a [-0.9932335]%
# Actually: 1, with a cost of [4.57855664e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311953]%
# Actually: 1, with a cost of [4.73408973e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931259]%
# Actually: 1, with a cost of [4.72532055e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99326039]%
# Actually: 1, with a cost of [4.54222979e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311786]%
# Actually: 1, with a cost of [4.73638056e-05]
# Computer: 1, with a [-0.99311914]%
# Actually: 1, with a cost of [4.73461931e-05]
# Computer: 1, with a [-0.99311792]%
# Actually: 1, with a cost of [4.73630302e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341336]%
# Actually: 0, with a cost of [0.00217032]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99352734]%
# Actually: 1, with a cost of [4.18953885e-05]
# Computer: 1, with a [-0.99313146]%
# Actually: 1, with a cost of [4.71768778e-05]
# Computer: 1, with a [-0.99311786]%
# Actually: 1, with a cost of [4.73637858e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311981]%
# Actually: 1, with a cost of [4.73369944e-05]
# Computer: 1, with a [-0.99312075]%
# Actually: 1, with a cost of [4.73240877e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341336]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312014]%
# Actually: 1, with a cost of [4.7332436e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311797]%
# Actually: 1, with a cost of [4.73623166e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99430728]%
# Actually: 1, with a cost of [3.24070489e-05]
# Computer: 1, with a [-0.99311792]%
# Actually: 1, with a cost of [4.73629957e-05]
# Computer: 1, with a [-0.99311792]%
# Actually: 1, with a cost of [4.73629614e-05]
# Computer: 1, with a [-0.9931179]%
# Actually: 1, with a cost of [4.73633309e-05]
# Computer: 1, with a [-0.99313219]%
# Actually: 1, with a cost of [4.71667756e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9937975]%
# Actually: 1, with a cost of [3.84710427e-05]
# Computer: 1, with a [-0.99312821]%
# Actually: 1, with a cost of [4.72214823e-05]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73637788e-05]
# Computer: 1, with a [-0.99312158]%
# Actually: 1, with a cost of [4.73126677e-05]
# Computer: 1, with a [-0.99441593]%
# Actually: 1, with a cost of [3.11818595e-05]
# Computer: 1, with a [-0.99312997]%
# Actually: 1, with a cost of [4.71973083e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99332764]%
# Actually: 1, with a cost of [4.45203408e-05]
# Computer: 1, with a [-0.99373056]%
# Actually: 1, with a cost of [3.93058959e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312472]%
# Actually: 1, with a cost of [4.7269485e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311419]%
# Actually: 1, with a cost of [4.74143121e-05]
# Computer: 1, with a [-0.99315358]%
# Actually: 1, with a cost of [4.68734459e-05]
# Computer: 1, with a [-0.99313519]%
# Actually: 1, with a cost of [4.71255578e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312205]%
# Actually: 1, with a cost of [4.73061899e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9930052]%
# Actually: 1, with a cost of [4.89271595e-05]
# Computer: 1, with a [-0.99311794]%
# Actually: 1, with a cost of [4.73627907e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311796]%
# Actually: 1, with a cost of [4.73625062e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.75536662]%
# Actually: 1, with a cost of [0.57057874]
# Computer: 1, with a [-0.99311907]%
# Actually: 1, with a cost of [4.73471645e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9945175]%
# Actually: 1, with a cost of [3.00578273e-05]
# Computer: 1, with a [-0.99311789]%
# Actually: 1, with a cost of [4.73634218e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311783]%
# Actually: 1, with a cost of [4.73642354e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9930072]%
# Actually: 1, with a cost of [4.88992832e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931191]%
# Actually: 1, with a cost of [4.73467414e-05]
# Computer: 1, with a [-0.99311786]%
# Actually: 1, with a cost of [4.73638187e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311797]%
# Actually: 1, with a cost of [4.73623354e-05]
# Computer: 1, with a [-0.99311799]%
# Actually: 1, with a cost of [4.73620774e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99310314]%
# Actually: 1, with a cost of [4.75666369e-05]
# Computer: 1, with a [-0.99320667]%
# Actually: 1, with a cost of [4.61493976e-05]
# Computer: 1, with a [-0.99314859]%
# Actually: 1, with a cost of [4.69418839e-05]
# Computer: 1, with a [-0.99369549]%
# Actually: 1, with a cost of [3.97468804e-05]
# Computer: 1, with a [-0.99322673]%
# Actually: 1, with a cost of [4.58771268e-05]
# Computer: 1, with a [-0.77746726]%
# Actually: 1, with a cost of [0.04952082]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931179]%
# Actually: 1, with a cost of [4.7363263e-05]
# Computer: 1, with a [-0.99486682]%
# Actually: 1, with a cost of [2.63495146e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931267]%
# Actually: 1, with a cost of [4.72422748e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99435193]%
# Actually: 1, with a cost of [3.1900722e-05]
# Computer: 1, with a [-0.99311801]%
# Actually: 1, with a cost of [4.73618139e-05]
# Computer: 1, with a [-0.99355816]%
# Actually: 1, with a cost of [4.14972491e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99455367]%
# Actually: 1, with a cost of [2.96624907e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311714]%
# Actually: 1, with a cost of [4.73737903e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931198]%
# Actually: 1, with a cost of [4.73372152e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.92540618]%
# Actually: 1, with a cost of [0.00556424]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311799]%
# Actually: 1, with a cost of [4.7362037e-05]
# Computer: 1, with a [-0.91759984]%
# Actually: 1, with a cost of [0.00678979]
# Computer: 1, with a [-0.99311834]%
# Actually: 1, with a cost of [4.73572806e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931222]%
# Actually: 1, with a cost of [4.73040698e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99314734]%
# Actually: 1, with a cost of [4.69589605e-05]
# Computer: 1, with a [-0.99311804]%
# Actually: 1, with a cost of [4.73613273e-05]
# Computer: 1, with a [-0.99311925]%
# Actually: 1, with a cost of [4.73447166e-05]
# Computer: 1, with a [-0.99326606]%
# Actually: 1, with a cost of [4.53459752e-05]
# Computer: 1, with a [-0.99311791]%
# Actually: 1, with a cost of [4.7363146e-05]
# Computer: 1, with a [-0.99311717]%
# Actually: 1, with a cost of [4.73734053e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311964]%
# Actually: 1, with a cost of [4.73392977e-05]
# Computer: 1, with a [-0.99362462]%
# Actually: 1, with a cost of [4.06454828e-05]
# Computer: 1, with a [-0.99311923]%
# Actually: 1, with a cost of [4.73449354e-05]
# Computer: 1, with a [-0.98928874]%
# Actually: 1, with a cost of [0.00011473]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312105]%
# Actually: 1, with a cost of [4.73200005e-05]
# Computer: 1, with a [-0.99311813]%
# Actually: 1, with a cost of [4.73600795e-05]
# Computer: 1, with a [-0.9931169]%
# Actually: 1, with a cost of [4.73771317e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311843]%
# Actually: 1, with a cost of [4.73559493e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9749388]%
# Actually: 1, with a cost of [0.00062806]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73636548e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311794]%
# Actually: 1, with a cost of [4.73627385e-05]
# Computer: 1, with a [-0.9942437]%
# Actually: 1, with a cost of [3.31349444e-05]
# Computer: 1, with a [-0.99312547]%
# Actually: 1, with a cost of [4.72591617e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73637254e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99448466]%
# Actually: 1, with a cost of [3.04189449e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99366816]%
# Actually: 1, with a cost of [4.00921417e-05]
# Computer: 1, with a [-0.99065088]%
# Actually: 1, with a cost of [8.74060595e-05]
# Computer: 1, with a [-0.99314045]%
# Actually: 1, with a cost of [4.70534776e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.98452728]%
# Actually: 1, with a cost of [0.00023941]
# Computer: 1, with a [-0.9940406]%
# Actually: 1, with a cost of [3.5514391e-05]
# Computer: 1, with a [-0.99341452]%
# Actually: 1, with a cost of [4.33685132e-05]
# Computer: 1, with a [-0.99313663]%
# Actually: 1, with a cost of [4.71057831e-05]
# Computer: 1, with a [-0.99422207]%
# Actually: 1, with a cost of [3.3384473e-05]
# Computer: 0, with a [0.95341314]%
# Actually: 0, with a cost of [0.00217034]
# Computer: 1, with a [-0.9905906]%
# Actually: 1, with a cost of [8.85368007e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99406822]%
# Actually: 1, with a cost of [3.51860285e-05]
# Computer: 1, with a [-0.99404685]%
# Actually: 1, with a cost of [3.5440048e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312075]%
# Actually: 1, with a cost of [4.73240263e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9948844]%
# Actually: 1, with a cost of [2.61694118e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99359041]%
# Actually: 1, with a cost of [4.10828324e-05]
# Computer: 1, with a [-0.99311793]%
# Actually: 1, with a cost of [4.73629043e-05]
# Computer: 1, with a [-0.99311795]%
# Actually: 1, with a cost of [4.7362678e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99316194]%
# Actually: 1, with a cost of [4.67590455e-05]
# Computer: 1, with a [-0.99129486]%
# Actually: 1, with a cost of [7.57794101e-05]
# Computer: 1, with a [-0.99486311]%
# Actually: 1, with a cost of [2.63876633e-05]
# Computer: 1, with a [-0.99312303]%
# Actually: 1, with a cost of [4.72927402e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.93814187]%
# Actually: 1, with a cost of [0.88011016]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.97224052]%
# Actually: 1, with a cost of [0.00077059]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311809]%
# Actually: 1, with a cost of [4.73607333e-05]
# Computer: 1, with a [-0.99311829]%
# Actually: 1, with a cost of [4.73579381e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311796]%
# Actually: 1, with a cost of [4.73624727e-05]
# Computer: 1, with a [-0.99311865]%
# Actually: 1, with a cost of [4.7353035e-05]
# Computer: 1, with a [-0.99311794]%
# Actually: 1, with a cost of [4.736273e-05]
# Computer: 1, with a [-0.993118]%
# Actually: 1, with a cost of [4.73619695e-05]
# Computer: 0, with a [0.95341336]%
# Actually: 1, with a cost of [0.90899704]
# Computer: 1, with a [-0.99311996]%
# Actually: 1, with a cost of [4.73349684e-05]
# Computer: 1, with a [-0.97370191]%
# Actually: 1, with a cost of [0.00069159]
# Computer: 1, with a [-0.99312128]%
# Actually: 1, with a cost of [4.73167855e-05]
# Computer: 1, with a [-0.99311841]%
# Actually: 1, with a cost of [4.73562478e-05]
# Computer: 1, with a [-0.99348609]%
# Actually: 1, with a cost of [4.24310138e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311829]%
# Actually: 1, with a cost of [4.73579277e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99331556]%
# Actually: 1, with a cost of [4.46817598e-05]
# Computer: 1, with a [-0.99326523]%
# Actually: 1, with a cost of [4.5357117e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931232]%
# Actually: 1, with a cost of [4.72904139e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312728]%
# Actually: 1, with a cost of [4.72343109e-05]
# Computer: 1, with a [-0.99311443]%
# Actually: 1, with a cost of [4.74110198e-05]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73636888e-05]
# Computer: 1, with a [-0.99443157]%
# Actually: 1, with a cost of [3.10074341e-05]
# Computer: 1, with a [-0.99311799]%
# Actually: 1, with a cost of [4.73620113e-05]
# Computer: 0, with a [0.85397359]%
# Actually: 1, with a cost of [0.72927089]
# Computer: 1, with a [-0.99312489]%
# Actually: 1, with a cost of [4.7267073e-05]
# Computer: 1, with a [-0.99314043]%
# Actually: 1, with a cost of [4.70536662e-05]
# Computer: 0, with a [0.95341336]%
# Actually: 0, with a cost of [0.00217032]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341336]%
# Actually: 0, with a cost of [0.00217032]
# Computer: 1, with a [-0.99319196]%
# Actually: 1, with a cost of [4.63493479e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99296653]%
# Actually: 1, with a cost of [4.94696723e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312543]%
# Actually: 1, with a cost of [4.72596623e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312117]%
# Actually: 1, with a cost of [4.73182621e-05]
# Computer: 1, with a [-0.99310381]%
# Actually: 1, with a cost of [4.75574172e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311806]%
# Actually: 1, with a cost of [4.736115e-05]
# Computer: 1, with a [-0.9947086]%
# Actually: 1, with a cost of [2.79988885e-05]
# Computer: 1, with a [-0.75031452]%
# Actually: 1, with a cost of [0.06234284]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99320215]%
# Actually: 1, with a cost of [4.62108272e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.97369438]%
# Actually: 1, with a cost of [0.00069199]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99488858]%
# Actually: 1, with a cost of [2.61266385e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311907]%
# Actually: 1, with a cost of [4.73471309e-05]
# Computer: 1, with a [-0.99314346]%
# Actually: 1, with a cost of [4.70121672e-05]
# Computer: 1, with a [-0.99311699]%
# Actually: 1, with a cost of [4.73758379e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73637586e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99335246]%
# Actually: 1, with a cost of [4.41897499e-05]
# Computer: 1, with a [-0.9931178]%
# Actually: 1, with a cost of [4.73646875e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341312]%
# Actually: 0, with a cost of [0.00217034]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99330736]%
# Actually: 1, with a cost of [4.47913944e-05]
# Computer: 1, with a [-0.99311849]%
# Actually: 1, with a cost of [4.73552132e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311018]%
# Actually: 1, with a cost of [4.74696879e-05]
# Computer: 1, with a [-0.99391947]%
# Actually: 1, with a cost of [3.69728914e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931176]%
# Actually: 1, with a cost of [4.73674844e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312059]%
# Actually: 1, with a cost of [4.73263263e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311788]%
# Actually: 1, with a cost of [4.73636314e-05]
# Computer: 1, with a [-0.99485646]%
# Actually: 1, with a cost of [2.64560492e-05]
# Computer: 1, with a [-0.99311926]%
# Actually: 1, with a cost of [4.73446334e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99330742]%
# Actually: 1, with a cost of [4.47906562e-05]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73637604e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99316571]%
# Actually: 1, with a cost of [4.67074942e-05]
# Computer: 0, with a [0.62341749]%
# Actually: 1, with a cost of [0.38864937]
# Computer: 1, with a [-0.99337946]%
# Actually: 1, with a cost of [4.38314983e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311707]%
# Actually: 1, with a cost of [4.73747575e-05]
# Computer: 1, with a [-0.97854612]%
# Actually: 1, with a cost of [0.00046027]
# Computer: 1, with a [-0.99311789]%
# Actually: 1, with a cost of [4.736343e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73636784e-05]
# Computer: 1, with a [-0.9931783]%
# Actually: 1, with a cost of [4.65355367e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311429]%
# Actually: 1, with a cost of [4.74130068e-05]
# Computer: 1, with a [-0.99343852]%
# Actually: 1, with a cost of [4.30530372e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99314207]%
# Actually: 1, with a cost of [4.70311365e-05]
# Computer: 1, with a [-0.99312012]%
# Actually: 1, with a cost of [4.73327663e-05]
# Computer: 1, with a [-0.99311785]%
# Actually: 1, with a cost of [4.73639599e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99292782]%
# Actually: 1, with a cost of [5.00157062e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99075522]%
# Actually: 1, with a cost of [8.54659377e-05]
# Computer: 1, with a [-0.99311838]%
# Actually: 1, with a cost of [4.73567427e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312755]%
# Actually: 1, with a cost of [4.72305891e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.89875526]%
# Actually: 1, with a cost of [0.0102505]
# Computer: 1, with a [-0.99373692]%
# Actually: 1, with a cost of [3.92261706e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99315555]%
# Actually: 1, with a cost of [4.68465073e-05]
# Computer: 1, with a [-0.99315216]%
# Actually: 1, with a cost of [4.68928896e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99310261]%
# Actually: 1, with a cost of [4.75739362e-05]
# Computer: 1, with a [-0.99311877]%
# Actually: 1, with a cost of [4.73513036e-05]
# Computer: 1, with a [-0.99311874]%
# Actually: 1, with a cost of [4.73517674e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.78232801]%
# Actually: 1, with a cost of [0.0473811]
# Computer: 1, with a [-0.99313327]%
# Actually: 1, with a cost of [4.71519948e-05]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73637064e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311806]%
# Actually: 1, with a cost of [4.73611359e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.54648328]%
# Actually: 1, with a cost of [0.20567742]
# Computer: 1, with a [-0.99311836]%
# Actually: 1, with a cost of [4.73569024e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931256]%
# Actually: 1, with a cost of [4.72574142e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311788]%
# Actually: 1, with a cost of [4.73635643e-05]
# Computer: 1, with a [-0.9931279]%
# Actually: 1, with a cost of [4.72256901e-05]
# Computer: 1, with a [-0.99311955]%
# Actually: 1, with a cost of [4.73405505e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931865]%
# Actually: 1, with a cost of [4.64237227e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99316665]%
# Actually: 1, with a cost of [4.66946455e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312305]%
# Actually: 1, with a cost of [4.72924638e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312005]%
# Actually: 1, with a cost of [4.73336726e-05]
# Computer: 0, with a [0.95341189]%
# Actually: 0, with a cost of [0.00217045]
# Computer: 1, with a [-0.99314001]%
# Actually: 1, with a cost of [4.70595061e-05]
# Computer: 1, with a [-0.99311818]%
# Actually: 1, with a cost of [4.73594134e-05]
# Computer: 0, with a [0.95341337]%
# ...
# Actually: 1, with a cost of [0.00022365]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.76095813]%
# Actually: 1, with a cost of [0.05714102]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311538]%
# Actually: 1, with a cost of [4.73979815e-05]
# Computer: 1, with a [-0.99312021]%
# Actually: 1, with a cost of [4.73315249e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99317609]%
# Actually: 1, with a cost of [4.65657666e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.98074938]%
# Actually: 1, with a cost of [0.00037059]
# Computer: 1, with a [-0.99311781]%
# Actually: 1, with a cost of [4.73645547e-05]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73637681e-05]
# Computer: 1, with a [-0.99311783]%
# Actually: 1, with a cost of [4.73642274e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311975]%
# Actually: 1, with a cost of [4.73377759e-05]
# Computer: 1, with a [-0.99311793]%
# Actually: 1, with a cost of [4.73628852e-05]
# Computer: 1, with a [-0.99311761]%
# Actually: 1, with a cost of [4.73672848e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312058]%
# Actually: 1, with a cost of [4.7326355e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99308749]%
# Actually: 1, with a cost of [4.77827423e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311762]%
# Actually: 1, with a cost of [4.73671668e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.97954789]%
# Actually: 1, with a cost of [0.00041829]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311786]%
# Actually: 1, with a cost of [4.73637841e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99309189]%
# Actually: 1, with a cost of [4.77220525e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931178]%
# Actually: 1, with a cost of [4.73646538e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99299858]%
# Actually: 1, with a cost of [4.90198501e-05]
# Computer: 1, with a [-0.99311748]%
# Actually: 1, with a cost of [4.7369137e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99469078]%
# Actually: 1, with a cost of [2.81877708e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.98917874]%
# Actually: 1, with a cost of [0.0001171]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99313217]%
# Actually: 1, with a cost of [4.71670963e-05]
# Computer: 1, with a [-0.99312235]%
# Actually: 1, with a cost of [4.73020249e-05]
# Computer: 1, with a [-0.99311856]%
# Actually: 1, with a cost of [4.73542417e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312547]%
# Actually: 1, with a cost of [4.72591187e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311874]%
# Actually: 1, with a cost of [4.7351774e-05]
# Computer: 1, with a [-0.99312776]%
# Actually: 1, with a cost of [4.72277413e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99479264]%
# Actually: 1, with a cost of [2.71165569e-05]
# Computer: 1, with a [-0.99408065]%
# Actually: 1, with a cost of [3.50386559e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311884]%
# Actually: 1, with a cost of [4.73503848e-05]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73636762e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312349]%
# Actually: 1, with a cost of [4.7286366e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99317109]%
# Actually: 1, with a cost of [4.66340469e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99317668]%
# Actually: 1, with a cost of [4.655766e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99310595]%
# Actually: 1, with a cost of [4.75279851e-05]
# Computer: 1, with a [-0.99363695]%
# Actually: 1, with a cost of [4.04884665e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99397368]%
# Actually: 1, with a cost of [3.6316523e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99326806]%
# Actually: 1, with a cost of [4.53189939e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99374042]%
# Actually: 1, with a cost of [3.91823886e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311946]%
# Actually: 1, with a cost of [4.73418329e-05]
# Computer: 1, with a [-0.99311792]%
# Actually: 1, with a cost of [4.73630696e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99331389]%
# Actually: 1, with a cost of [4.47040073e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99430711]%
# Actually: 1, with a cost of [3.24089431e-05]
# Computer: 1, with a [-0.9948292]%
# Actually: 1, with a cost of [2.67371711e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311846]%
# Actually: 1, with a cost of [4.73556569e-05]
# Computer: 1, with a [-0.99311807]%
# Actually: 1, with a cost of [4.73608932e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311802]%
# Actually: 1, with a cost of [4.73617163e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311887]%
# Actually: 1, with a cost of [4.7349907e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931179]%
# Actually: 1, with a cost of [4.7363333e-05]
# Computer: 1, with a [-0.9931179]%
# Actually: 1, with a cost of [4.73633356e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931198]%
# Actually: 1, with a cost of [4.73371509e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311784]%
# Actually: 1, with a cost of [4.73640731e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311861]%
# Actually: 1, with a cost of [4.73535361e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931178]%
# Actually: 1, with a cost of [4.73646668e-05]
# Computer: 1, with a [-0.99311787]%
# Actually: 1, with a cost of [4.73637117e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311736]%
# Actually: 1, with a cost of [4.73707613e-05]
# Computer: 1, with a [-0.9931182]%
# Actually: 1, with a cost of [4.73591536e-05]
# Computer: 1, with a [-0.99310758]%
# Actually: 1, with a cost of [4.75054274e-05]
# Computer: 1, with a [-0.99311786]%
# Actually: 1, with a cost of [4.73638854e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311929]%
# Actually: 1, with a cost of [4.73442367e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311304]%
# Actually: 1, with a cost of [4.74302808e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312086]%
# Actually: 1, with a cost of [4.7322603e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312972]%
# Actually: 1, with a cost of [4.72008008e-05]
# Computer: 1, with a [-0.65530616]%
# Actually: 1, with a cost of [0.11881385]
# Computer: 1, with a [-0.99316467]%
# Actually: 1, with a cost of [4.67217631e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99310766]%
# Actually: 1, with a cost of [4.75043935e-05]
# Computer: 1, with a [-0.96552856]%
# Actually: 1, with a cost of [0.00118828]
# Computer: 1, with a [-0.99313817]%
# Actually: 1, with a cost of [4.70846744e-05]
# Computer: 1, with a [-0.9931211]%
# Actually: 1, with a cost of [4.73192468e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99316834]%
# Actually: 1, with a cost of [4.6671538e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311803]%
# Actually: 1, with a cost of [4.73614594e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311797]%
# Actually: 1, with a cost of [4.736235e-05]
# Computer: 1, with a [-0.99311792]%
# Actually: 1, with a cost of [4.73629828e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311958]%
# Actually: 1, with a cost of [4.73401928e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312315]%
# Actually: 1, with a cost of [4.72911323e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312079]%
# Actually: 1, with a cost of [4.73235819e-05]
# Computer: 1, with a [-0.99314037]%
# Actually: 1, with a cost of [4.7054583e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99313489]%
# Actually: 1, with a cost of [4.71297441e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931189]%
# Actually: 1, with a cost of [4.73494979e-05]
# Computer: 1, with a [-0.99311865]%
# Actually: 1, with a cost of [4.73529634e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311045]%
# Actually: 1, with a cost of [4.74658944e-05]
# Computer: 1, with a [-0.99312119]%
# Actually: 1, with a cost of [4.73180641e-05]
# Computer: 1, with a [-0.99311858]%
# Actually: 1, with a cost of [4.7353998e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312602]%
# Actually: 1, with a cost of [4.72515469e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312592]%
# Actually: 1, with a cost of [4.72529488e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99309022]%
# Actually: 1, with a cost of [4.77450156e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311889]%
# Actually: 1, with a cost of [4.73496844e-05]
# Computer: 1, with a [-0.99312052]%
# Actually: 1, with a cost of [4.73272589e-05]
# Computer: 1, with a [-0.99316903]%
# Actually: 1, with a cost of [4.66621978e-05]
# Computer: 1, with a [-0.99316269]%
# Actually: 1, with a cost of [4.67487544e-05]
# Computer: 1, with a [-0.99313746]%
# Actually: 1, with a cost of [4.70944678e-05]
# Computer: 1, with a [-0.99311785]%
# Actually: 1, with a cost of [4.73640371e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311971]%
# Actually: 1, with a cost of [4.73384464e-05]
# Computer: 1, with a [-0.99311902]%
# Actually: 1, with a cost of [4.73478796e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99313946]%
# Actually: 1, with a cost of [4.70670118e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99314129]%
# Actually: 1, with a cost of [4.70419254e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311782]%
# Actually: 1, with a cost of [4.73644128e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.98416857]%
# Actually: 1, with a cost of [0.00025063]
# Computer: 1, with a [-0.99311859]%
# Actually: 1, with a cost of [4.73537489e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311918]%
# Actually: 1, with a cost of [4.73456955e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311983]%
# Actually: 1, with a cost of [4.73366939e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311937]%
# Actually: 1, with a cost of [4.73430311e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.835839]%
# Actually: 1, with a cost of [0.69862684]
# Computer: 1, with a [-0.99311816]%
# Actually: 1, with a cost of [4.73596806e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99312643]%
# Actually: 1, with a cost of [4.72459219e-05]
# Computer: 1, with a [-0.99311808]%
# Actually: 1, with a cost of [4.73608685e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.9931182]%
# Actually: 1, with a cost of [4.73592067e-05]
# Computer: 0, with a [0.95341337]%
# Actually: 0, with a cost of [0.00217031]
# Computer: 1, with a [-0.99311792]%
# Actually: 1, with a cost of [4.73630459e-05]
# Computer finished testing with a final accuracy of: 0.9858156028368794
